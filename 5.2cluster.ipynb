# %% [markdown]
# # Cluster
# Use clustering algorithm(K-means) to divide the total data by the Top 10 most important features into several similar groups

# %%
# import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
current_path = os.getcwd()

# %%
CLUSTER_NUMS = 3
RANDOM_STATE = 42

# Top 10 most important features
feature_importance_df = pd.read_csv(os.path.join(current_path, './metrics/feature_importance/mp_plus/plus_XGBoost_feature_importance.csv'))
top_importance = feature_importance_df['Feature'].tolist()
top_importance
# Out:
# ['mode ThermalConductivity',
#  'mode HeatVaporization',
#  'maximum Electronegativity',
#  'minimum HeatVaporization',
#  'minimum ThermalConductivity',
#  'range NfUnfilled',
#  'minimum GSestBCClatcnt',
#  'minimum AtomicVolume',
#  'minimum MolarVolume',
#  'maximum NUnfilled']

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'mp_plus_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mp_plus_test_set.csv'))

dft_train.shape, dft_test.shape
# Out:
# ((7869, 130), (1963, 130))

# %%
kmeans = KMeans(n_clusters=CLUSTER_NUMS, random_state=RANDOM_STATE)

# %%
scaler = StandardScaler()
# Scale the data
scaled_X = scaler.fit_transform(dft_train[top_importance])
kmeans.fit(scaled_X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
dft_train['cluster'] = kmeans.labels_

# %%
# predict clusters for test data
scaled_test_X = scaler.transform(dft_test[top_importance])
dft_test['cluster'] = kmeans.predict(scaled_test_X)

# %%
dft_train.head()
# Out:
#     composition  nsites  crystal_system  space_group       volume   density  \
# 0     Ag2Au4F16      22               4           14   312.794323  6.941567
# 1    Ag8B48Cl48     104               0          205  1920.521818  2.666186
# 2  Ag40Te16Br12      68               3           63  1688.336988  7.194734
# 3  Ag30P8S32Cl6      76               0          220  1709.591255  4.587131
# 4     Ag8Bi4O12      24               3           34   366.571761  8.565436
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.217924 -1.966392       -14.614052                  -1.201868  ...
# 1       18.466556  0.446000        -8.609923                  -0.736951  ...
# 2       24.828485  2.536429        -3.067222                  -0.366432  ...
# 3       22.494622  2.458781        -4.062215                  -0.481548  ...
# 4       15.273823  3.026700        -4.987277                  -0.917311  ...
#
#    mean NpUnfilled  avg_dev NpUnfilled  mean NpValence  avg_dev NpValence  \
# 0         0.727273            0.396694        3.636364           1.983471
# 1         2.769231            2.059172        2.769231           2.059172
# 2         0.647059            0.761246        1.823529           2.145329
# 3         1.236842            1.013850        2.394737           1.890582
# 4         1.500000            1.000000        2.500000           1.666667
#
#    avg_dev NsValence  maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  \
# 0           0.396694                     2.660               0.994091
# 1           0.142012                     2.375               1.015769
# 2           0.484429                     2.375               2.001765
# 3           0.477839                     2.375               1.610921
# 4           0.444444                     2.375               1.357000
#
#    avg_dev ZungerPP-r_sigma  range ZungerPP-r_sigma  cluster
# 0                  0.856860                   2.255        2
# 1                  0.209112                   1.580        2
# 2                  0.439100                   1.175        1
# 3                  0.603220                   1.365        2
# 4                  0.892000                   1.910        2
#
# [5 rows x 131 columns]

# %%
dft_test.head()
# Out:
#       composition  nsites  crystal_system  space_group       volume   density  \
# 0  Ag12Ge6S36O126     180               6          147  2544.837686  3.197654
# 1    Ag8H16S12O48      84               3           33  1057.273255  3.191155
# 2      Ag16P8Se24      48               3           19  1108.881842  5.793370
# 3      Ag12Te6O24      42               4           15   571.396405  7.102537
# 4       Ag3As1F12      16               5            2   257.772769  4.035878
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.137987  0.457826        -6.234630                  -1.599755  ...
# 1       12.586586  0.517819        -5.785262                  -1.449207  ...
# 2       23.101705  2.942116       -15.944160                  -0.169408  ...
# 3       13.604676  3.100366        -5.053196                  -0.964478  ...
# 4       16.110798 -1.540041        -4.061584                  -1.801261  ...
#
#    mean NpUnfilled  avg_dev NpUnfilled  mean NpValence  avg_dev NpValence  \
# 0         1.933333            0.257778        3.666667           0.600000
# 1         1.428571            0.816327        2.857143           1.632653
# 2         1.500000            1.000000        2.500000           1.666667
# 3         1.428571            0.816327        2.857143           1.632653
# 4         0.937500            0.351562        3.937500           1.593750
#
#    avg_dev NsValence  maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  \
# 0           0.124444                     2.375               0.755833
# 1           0.408163                     2.375               0.887143
# 2           0.444444                     2.375               1.640833
# 3           0.408163                     2.375               1.182857
# 4           0.304688                     2.375               0.837500
#
#    avg_dev ZungerPP-r_sigma  range ZungerPP-r_sigma  cluster
# 0                  0.407167                   1.910        2
# 1                  0.482449                   1.910        2
# 2                  0.489444                   1.135        1
# 3                  0.820408                   1.910        2
# 4                  0.648750                   1.970        2
#
# [5 rows x 131 columns]

# %%
groups = dft_train.groupby('cluster')

# %%
for cluster, df in groups:
    print(f'Cluster {cluster}: {len(df)} samples')
    # display(df.head(5))
# Out:
# Cluster 0: 783 samples
# Cluster 1: 2440 samples
# Cluster 2: 4646 samples

# %%
# save the cluster data
dft_train.to_csv(os.path.join(file_dir, 'rfe_train_data', 'mp_plus_cluster_train_set.csv'), index=False)
dft_test.to_csv(os.path.join(file_dir, 'rfe_test_data', 'mp_plus_cluster_test_set.csv'), index=False)
