# %% [markdown]
# # Feature Engineering
# 对影响mp_plus最重要的**十个特征X**进行如下操作：
# - $X^2$
# - $exp(X)$
# - $log(|X|)$
# - $1/X$
# - $\sqrt{|X|}$
#
# 其中操作四五需要注意的是，$X$不能为0，因此在操作之前需要对$X$进行处理，将$X=0$的值替换为1e-6。
#
# 对影响mp_plus最重要的**五个特征Y**进行如下操作：
# - $Y_i + Y_j$ (i,j = 1,2,3,4,5)
# - $|Y_i - Y_j|$ (i,j = 1,2,3,4,5)
# - $Y_i * Y_j$ (i,j = 1,2,3,4,5)
# - $Y_i / Y_j$ (i,j = 1,2,3,4,5)
#
# 总共增加了$10*5 + 10*4 = 90$个特征。

# %%
# import libraries
import os
import sys
import numpy as np
import pandas as pd
# Set random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
current_path = os.getcwd()
current_path
# Out:
# 'c:\\Users\\Fortyfour\\Desktop\\graduation_design\\New_Scripts\\Bg_pre2'

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'mp_plus_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mp_plus_test_set.csv'))

# 
feat_importance_dir = os.path.join(current_path, 'metrics', 'feature_importance', 'mp_plus')
feat_importance = pd.read_csv(os.path.join(feat_importance_dir, 'plus_XGBoost_feature_importance.csv'))

# %%
(dft_train[feat_importance['Feature']]==0).any()
# Out:
# mode ThermalConductivity       False
# mode HeatVaporization          False
# maximum Electronegativity      False
# minimum HeatVaporization       False
# minimum ThermalConductivity    False
# range NfUnfilled                True
# minimum GSestBCClatcnt         False
# minimum AtomicVolume           False
# minimum MolarVolume            False
# maximum NUnfilled               True
# dtype: bool

# %%
# 进行特征工程1
for col in feat_importance['Feature']:
    # 计算对数值
    dft_train[col + '_log'] = np.log(np.abs(dft_train[col])+1e-6)  # 加1e-6避免对数为负无穷
    dft_test[col + '_log'] = np.log(np.abs(dft_test[col])+1e-6) 
    # 计算指数值
    # 归一化避免指数值过大
    dft_train[col + '_exp'] = np.exp(dft_train[col] / np.abs(dft_train[col]).max())
    dft_test[col + '_exp'] = np.exp(dft_test[col] / np.abs(dft_test[col]).max())
    # 计算倒数值
    dft_train[col + '_reciprocal'] = 1 / (dft_train[col]+1e-6)  # 加1e-6避免除数为0
    dft_test[col + '_reciprocal'] = 1 / (dft_test[col]+1e-6)
    # 计算平方值
    dft_train[col + '_square'] = dft_train[col] ** 2
    dft_test[col + '_square'] = dft_test[col] ** 2
    # 计算平方根值
    dft_train[col + '_sqrt'] = np.sqrt(np.abs(dft_train[col]))  # 加1e-6避免开方为负无穷
    dft_test[col + '_sqrt'] = np.sqrt(np.abs(dft_test[col]))

# %%
dft_train.head(5)
# Out:
#     composition  nsites  crystal_system  space_group       volume   density  \
# 0     Ag2Au4F16      22               4           14   312.794323  6.941567
# 1    Ag8B48Cl48     104               0          205  1920.521818  2.666186
# 2  Ag40Te16Br12      68               3           63  1688.336988  7.194734
# 3  Ag30P8S32Cl6      76               0          220  1709.591255  4.587131
# 4     Ag8Bi4O12      24               3           34   366.571761  8.565436
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.217924 -1.966392       -14.614052                  -1.201868  ...
# 1       18.466556  0.446000        -8.609923                  -0.736951  ...
# 2       24.828485  2.536429        -3.067222                  -0.366432  ...
# 3       22.494622  2.458781        -4.062215                  -0.481548  ...
# 4       15.273823  3.026700        -4.987277                  -0.917311  ...
#
#    minimum MolarVolume_log  minimum MolarVolume_exp  \
# 0                 2.323368                 1.487307
# 1                 1.479329                 1.186116
# 2                 2.329227                 1.490781
# 3                 2.329227                 1.490781
# 4                 2.329227                 1.490781
#
#    minimum MolarVolume_reciprocal  minimum MolarVolume_square  \
# 0                        0.097943                    104.2441
# 1                        0.227790                     19.2721
# 2                        0.097371                    105.4729
# 3                        0.097371                    105.4729
# 4                        0.097371                    105.4729
#
#    minimum MolarVolume_sqrt  maximum NUnfilled_log  maximum NUnfilled_exp  \
# 0                  3.195309           9.999995e-07               1.046503
# 1                  2.095233           1.609438e+00               1.255172
# 2                  3.204684           6.931477e-01               1.095169
# 3                  3.204684           1.098613e+00               1.146099
# 4                  3.204684           1.098613e+00               1.146099
#
#    maximum NUnfilled_reciprocal  maximum NUnfilled_square  \
# 0                      0.999999                       1.0
# 1                      0.200000                      25.0
# 2                      0.500000                       4.0
# 3                      0.333333                       9.0
# 4                      0.333333                       9.0
#
#    maximum NUnfilled_sqrt
# 0                1.000000
# 1                2.236068
# 2                1.414214
# 3                1.732051
# 4                1.732051
#
# [5 rows x 180 columns]

# %%
important_features_five = feat_importance['Feature'].head(5).tolist()
important_features_five
# Out:
# ['mode ThermalConductivity',
#  'mode HeatVaporization',
#  'maximum Electronegativity',
#  'minimum HeatVaporization',
#  'minimum ThermalConductivity']

# %%
# 进行特征工程2
for i in range(0, 5):
    for j in range(i + 1, 5):
        i_col = important_features_five[i]
        j_col = important_features_five[j]
        # 计算加法
        dft_train[i_col + '_' + j_col + '_add'] = dft_train[i_col] + dft_train[j_col]
        dft_test[i_col + '_' + j_col + '_add'] = dft_test[i_col] + dft_test[j_col]
        # 计算减法
        dft_train[i_col + '_' + j_col + '_sub'] = np.abs(dft_train[i_col] - dft_train[j_col])
        dft_test[i_col + '_' + j_col + '_sub'] = np.abs(dft_test[i_col] - dft_test[j_col])
        # 计算乘法
        dft_train[i_col + '_' + j_col + '_mul'] = dft_train[i_col] * dft_train[j_col]
        dft_test[i_col + '_' + j_col + '_mul'] = dft_test[i_col] * dft_test[j_col]
        # 计算除法
        dft_train[i_col + '_' + j_col + '_div'] = dft_train[i_col] / (dft_train[j_col] + 1e-6)
        dft_test[i_col + '_' + j_col + '_div'] = dft_test[i_col] / (dft_test[j_col] + 1e-6)

# %%
dft_train.head(5)
# Out:
#     composition  nsites  crystal_system  space_group       volume   density  \
# 0     Ag2Au4F16      22               4           14   312.794323  6.941567
# 1    Ag8B48Cl48     104               0          205  1920.521818  2.666186
# 2  Ag40Te16Br12      68               3           63  1688.336988  7.194734
# 3  Ag30P8S32Cl6      76               0          220  1709.591255  4.587131
# 4     Ag8Bi4O12      24               3           34   366.571761  8.565436
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.217924 -1.966392       -14.614052                  -1.201868  ...
# 1       18.466556  0.446000        -8.609923                  -0.736951  ...
# 2       24.828485  2.536429        -3.067222                  -0.366432  ...
# 3       22.494622  2.458781        -4.062215                  -0.481548  ...
# 4       15.273823  3.026700        -4.987277                  -0.917311  ...
#
#    maximum Electronegativity_minimum HeatVaporization_mul  \
# 0                                            13.0146
# 1                                            32.2320
# 2                                            43.8080
# 3                                            30.9680
# 4                                            11.7304
#
#    maximum Electronegativity_minimum HeatVaporization_div  \
# 0                                           1.217125
# 1                                           0.309804
# 2                                           0.200000
# 3                                           0.322449
# 4                                           1.008797
#
#    maximum Electronegativity_minimum ThermalConductivity_add  \
# 0                                            4.00770
# 1                                            3.16890
# 2                                            3.08000
# 3                                            3.16890
# 4                                            3.46658
#
#    maximum Electronegativity_minimum ThermalConductivity_sub  \
# 0                                            3.95230
# 1                                            3.15110
# 2                                            2.84000
# 3                                            3.15110
# 4                                            3.41342
#
#    maximum Electronegativity_minimum ThermalConductivity_mul  \
# 0                                           0.110246
# 1                                           0.028124
# 2                                           0.355200
# 3                                           0.028124
# 4                                           0.091435
#
#    maximum Electronegativity_minimum ThermalConductivity_div  \
# 0                                         143.677124
# 1                                         355.016290
# 2                                          24.666461
# 3                                         355.016290
# 4                                         129.415748
#
#    minimum HeatVaporization_minimum ThermalConductivity_add  \
# 0                                            3.29770
# 1                                           10.20890
# 2                                           14.92000
# 3                                            9.80890
# 4                                            3.43658
#
#    minimum HeatVaporization_minimum ThermalConductivity_sub  \
# 0                                            3.24230
# 1                                           10.19110
# 2                                           14.68000
# 3                                            9.79110
# 4                                            3.38342
#
#    minimum HeatVaporization_minimum ThermalConductivity_mul  \
# 0                                           0.090579
# 1                                           0.090780
# 2                                           1.776000
# 3                                           0.087220
# 4                                           0.090638
#
#    minimum HeatVaporization_minimum ThermalConductivity_div
# 0                                         118.046280
# 1                                        1145.938659
# 2                                         123.332306
# 3                                        1100.999888
# 4                                         128.287122
#
# [5 rows x 220 columns]

# %%
dft_test.head(5)
# Out:
#       composition  nsites  crystal_system  space_group       volume   density  \
# 0  Ag12Ge6S36O126     180               6          147  2544.837686  3.197654
# 1    Ag8H16S12O48      84               3           33  1057.273255  3.191155
# 2      Ag16P8Se24      48               3           19  1108.881842  5.793370
# 3      Ag12Te6O24      42               4           15   571.396405  7.102537
# 4       Ag3As1F12      16               5            2   257.772769  4.035878
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.137987  0.457826        -6.234630                  -1.599755  ...
# 1       12.586586  0.517819        -5.785262                  -1.449207  ...
# 2       23.101705  2.942116       -15.944160                  -0.169408  ...
# 3       13.604676  3.100366        -5.053196                  -0.964478  ...
# 4       16.110798 -1.540041        -4.061584                  -1.801261  ...
#
#    maximum Electronegativity_minimum HeatVaporization_mul  \
# 0                                           11.73040
# 1                                            1.55488
# 2                                           31.62000
# 3                                           11.73040
# 4                                           13.01460
#
#    maximum Electronegativity_minimum HeatVaporization_div  \
# 0                                           1.008797
# 1                                           7.610603
# 2                                           0.205645
# 3                                           1.008797
# 4                                           1.217125
#
#    maximum Electronegativity_minimum ThermalConductivity_add  \
# 0                                            3.46658
# 1                                            3.46658
# 2                                            2.78600
# 3                                            3.46658
# 4                                            4.00770
#
#    maximum Electronegativity_minimum ThermalConductivity_sub  \
# 0                                            3.41342
# 1                                            3.41342
# 2                                            2.31400
# 3                                            3.41342
# 4                                            3.95230
#
#    maximum Electronegativity_minimum ThermalConductivity_mul  \
# 0                                           0.091435
# 1                                           0.091435
# 2                                           0.601800
# 3                                           0.091435
# 4                                           0.110246
#
#    maximum Electronegativity_minimum ThermalConductivity_div  \
# 0                                         129.415748
# 1                                         129.415748
# 2                                          10.805039
# 3                                         129.415748
# 4                                         143.677124
#
#    minimum HeatVaporization_minimum ThermalConductivity_add  \
# 0                                            3.43658
# 1                                            0.47858
# 2                                           12.63600
# 3                                            3.43658
# 4                                            3.29770
#
#    minimum HeatVaporization_minimum ThermalConductivity_sub  \
# 0                                            3.38342
# 1                                            0.42542
# 2                                           12.16400
# 3                                            3.38342
# 4                                            3.24230
#
#    minimum HeatVaporization_minimum ThermalConductivity_mul  \
# 0                                           0.090638
# 1                                           0.012014
# 2                                           2.926400
# 3                                           0.090638
# 4                                           0.090579
#
#    minimum HeatVaporization_minimum ThermalConductivity_div
# 0                                         128.287122
# 1                                          17.004627
# 2                                          52.542150
# 3                                         128.287122
# 4                                         118.046280
#
# [5 rows x 220 columns]

# %%
# 保存数据
train_save_dir = os.path.join(current_path, 'Data', 'rfe_train_data')
test_save_dir = os.path.join(current_path, 'Data', 'rfe_test_data')
dft_train.to_csv(os.path.join(train_save_dir, 'mp_plus_engineered_train_set.csv'), index=False)
dft_test.to_csv(os.path.join(test_save_dir, 'mp_plus_engineered_test_set.csv'), index=False)
