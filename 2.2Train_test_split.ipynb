# %% [markdown]
# # Train Test Split

# %%
import os
import random
import pandas as pd

RANDOM_SEED = 42

# %%
# load data
mp_feature_df = pd.read_csv('./Data/featured_data/mp_elements_feat.csv')
exp_feature_df = pd.read_csv('./Data/featured_data/exp_elements_feat.csv')
mp_feature_plus_df = pd.read_csv('./Data/featured_data/mp_elements_plus_feat.csv')

# %%
mp_feature_df.head()
# Out:
#     composition  band_gap  minimum Number  maximum Number  mean Number  \
# 0     Ag2Au4F16    0.2585             9.0            79.0    25.181818
# 1    Ag8B48Cl48    2.7028             5.0            47.0    13.769231
# 2  Ag40Te16Br12    0.8722            35.0            52.0    46.058824
# 3  Ag30P8S32Cl6    1.2888            15.0            47.0    28.210526
# 4     Ag8Bi4O12    0.3872             8.0            83.0    33.500000
#
#    avg_dev Number  range Number  mode Number  minimum AtomicRadius  \
# 0       23.537190          70.0          9.0                  0.50
# 1        8.094675          42.0          5.0                  0.85
# 2        3.903114          17.0         47.0                  1.15
# 3       14.833795          32.0         16.0                  1.00
# 4       25.500000          75.0          8.0                  0.60
#
#    maximum AtomicRadius  ...  mean NsValence  avg_dev NsValence  \
# 0                   1.6  ...        1.727273           0.396694
# 1                   1.6  ...        1.923077           0.142012
# 2                   1.6  ...        1.411765           0.484429
# 3                   1.6  ...        1.605263           0.477839
# 4                   1.6  ...        1.666667           0.444444
#
#    range NsValence  mode NsValence  minimum ZungerPP-r_sigma  \
# 0              1.0             2.0                     0.405
# 1              1.0             2.0                     0.795
# 2              1.0             1.0                     1.200
# 3              1.0             2.0                     1.010
# 4              1.0             2.0                     0.465
#
#    maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  avg_dev ZungerPP-r_sigma  \
# 0                     2.660               0.994091                  0.856860
# 1                     2.375               1.015769                  0.209112
# 2                     2.375               2.001765                  0.439100
# 3                     2.375               1.610921                  0.603220
# 4                     2.375               1.357000                  0.892000
#
#    range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   2.255                  0.405
# 1                   1.580                  0.795
# 2                   1.175                  2.375
# 3                   1.365                  1.100
# 4                   1.910                  0.465
#
# [5 rows x 230 columns]

# %%
exp_feature_df.head()
# Out:
#      composition  band_gap  minimum Number  maximum Number  mean Number  \
# 0  Hg0.7Cd0.3Te1      0.35            48.0            80.0    61.200000
# 1          Lu1P1      1.30            15.0            71.0    43.000000
# 2      Cu3Sb1Se4      0.40            29.0            51.0    34.250000
# 3         Pt1Sb2      0.08            51.0            78.0    60.000000
# 4       Zn1In2S4      2.68            16.0            49.0    27.428571
#
#    avg_dev Number  range Number  mode Number  minimum AtomicRadius  \
# 0       13.160000          32.0         52.0                  1.40
# 1       28.000000          56.0         15.0                  1.00
# 2        4.187500          22.0         34.0                  1.15
# 3       12.000000          27.0         51.0                  1.35
# 4       13.061224          33.0         16.0                  1.00
#
#    maximum AtomicRadius  ...  mean NsValence  avg_dev NsValence  \
# 0                  1.55  ...        2.000000           0.000000
# 1                  1.75  ...        2.000000           0.000000
# 2                  1.45  ...        1.625000           0.468750
# 3                  1.45  ...        1.666667           0.444444
# 4                  1.55  ...        2.000000           0.000000
#
#    range NsValence  mode NsValence  minimum ZungerPP-r_sigma  \
# 0              0.0             2.0                     1.670
# 1              0.0             2.0                     1.240
# 2              1.0             2.0                     1.285
# 3              1.0             2.0                     1.765
# 4              0.0             2.0                     1.100
#
#    maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  avg_dev ZungerPP-r_sigma  \
# 0                      2.41               2.010750                  0.340750
# 1                      3.37               2.305000                  1.065000
# 2                      2.04               1.628125                  0.343125
# 3                      2.70               2.076667                  0.415556
# 4                      2.05               1.482857                  0.437551
#
#    range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   0.740                  1.670
# 1                   2.130                  1.240
# 2                   0.755                  1.285
# 3                   0.935                  1.765
# 4                   0.950                  1.100
#
# [5 rows x 230 columns]

# %%
mp_feature_plus_df.head()
# Out:
#     composition  nsites  crystal_system  space_group       volume   density  \
# 0     Ag2Au4F16      22               4           14   312.794323  6.941567
# 1    Ag8B48Cl48     104               0          205  1920.521818  2.666186
# 2  Ag40Te16Br12      68               3           63  1688.336988  7.194734
# 3  Ag30P8S32Cl6      76               0          220  1709.591255  4.587131
# 4     Ag8Bi4O12      24               3           34   366.571761  8.565436
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       14.217924 -1.966392       -14.614052                  -1.201868  ...
# 1       18.466556  0.446000        -8.609923                  -0.736951  ...
# 2       24.828485  2.536429        -3.067222                  -0.366432  ...
# 3       22.494622  2.458781        -4.062215                  -0.481548  ...
# 4       15.273823  3.026700        -4.987277                  -0.917311  ...
#
#    mean NsValence  avg_dev NsValence  range NsValence  mode NsValence  \
# 0        1.727273           0.396694              1.0             2.0
# 1        1.923077           0.142012              1.0             2.0
# 2        1.411765           0.484429              1.0             1.0
# 3        1.605263           0.477839              1.0             2.0
# 4        1.666667           0.444444              1.0             2.0
#
#    minimum ZungerPP-r_sigma  maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  \
# 0                     0.405                     2.660               0.994091
# 1                     0.795                     2.375               1.015769
# 2                     1.200                     2.375               2.001765
# 3                     1.010                     2.375               1.610921
# 4                     0.465                     2.375               1.357000
#
#    avg_dev ZungerPP-r_sigma  range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                  0.856860                   2.255                  0.405
# 1                  0.209112                   1.580                  0.795
# 2                  0.439100                   1.175                  2.375
# 3                  0.603220                   1.365                  1.100
# 4                  0.892000                   1.910                  0.465
#
# [5 rows x 241 columns]

# %%
mp_feature_df.shape, exp_feature_df.shape, mp_feature_plus_df.shape
# Out:
# ((9832, 230), (3109, 230), (9832, 241))

# %% [markdown]
# <!-- ### Remove High Related Features -->

# %%
print(f'MP测试集大概大小：{mp_feature_df.shape[0]*0.2}')
print(f'EXP测试集大概大小：{exp_feature_df.shape[0]*0.2}')
# Out:
# MP测试集大概大小：1966.4
# EXP测试集大概大小：621.8000000000001

# %%
mp_unique_comp = mp_feature_df['composition'].unique()
len(mp_unique_comp)
# Out:
# 9797

# %%
# 从mp_unique_comp中随机采样组成
random.seed(RANDOM_SEED)
random_index = random.sample(range(len(mp_unique_comp)), round(len(mp_unique_comp)*0.2))
mp_test_comp = mp_unique_comp[random_index]
mp_train_set = mp_feature_df[~mp_feature_df['composition'].isin(mp_test_comp)]
mp_test_set = mp_feature_df[mp_feature_df['composition'].isin(mp_test_comp)]
print(f'MP训练集大小：{len(mp_train_set)}')
print(f'MP测试集大小：{len(mp_test_set)}')
# Out:
# MP训练集大小：7869
# MP测试集大小：1963

# %%
mp_plus_train_set = mp_feature_plus_df[~mp_feature_plus_df['composition'].isin(mp_test_comp)]
mp_plus_test_set = mp_feature_plus_df[mp_feature_plus_df['composition'].isin(mp_test_comp)]
print(f'MP Plus训练集大小：{len(mp_plus_train_set)}')
print(f'MP Plus测试集大小：{len(mp_plus_test_set)}')
# Out:
# MP Plus训练集大小：7869
# MP Plus测试集大小：1963

# %%
exp_unique_comp = exp_feature_df['composition'].unique()
len(exp_unique_comp)
# Out:
# 1955

# %%
# 从exp_unique_comp中随机采样n种组成
random_index = random.sample(range(len(exp_unique_comp)), round(len(exp_unique_comp)*0.2))
exp_test_comp = exp_unique_comp[random_index]
exp_train_set = exp_feature_df[~exp_feature_df['composition'].isin(exp_test_comp)]
exp_test_set = exp_feature_df[exp_feature_df['composition'].isin(exp_test_comp)]
print(f'EXP训练集大小：{len(exp_train_set)}')
print(f'EXP测试集大小：{len(exp_test_set)}')
# Out:
# EXP训练集大小：2510
# EXP测试集大小：599

# %%
# 混合测试集
# mp:exp = 1:1
mix_test_set = mp_test_set.sample(n=round(1*exp_test_set.shape[0])).reset_index(drop=True)

# %%
mix_test_set = pd.concat([mix_test_set, exp_test_set], axis=0).reset_index(drop=True)
mix_test_set = mix_test_set.sample(frac=1, random_state=RANDOM_SEED).reset_index(drop=True)
print(f'混合测试集大小：{len(mix_test_set)}')
# Out:
# 混合测试集大小：1198

# %%
mix_test_set.head()
# Out:
#     composition  band_gap  minimum Number  maximum Number  mean Number  \
# 0  Cu2Zn1Sn1Se4    1.4400            29.0            50.0    34.250000
# 1        Os1Sb2    0.3000            51.0            76.0    59.333333
# 2   Li4Cr3Fe1O8    2.3536             3.0            26.0    10.875000
# 3  Cs2Sm2Mn2Se6    0.5312            25.0            62.0    40.666667
# 4   Pr2Zn2Sb2O2    0.1208             8.0            59.0    37.000000
#
#    avg_dev Number  range Number  mode Number  minimum AtomicRadius  \
# 0        3.937500          21.0         34.0                  1.15
# 1       11.111111          25.0         51.0                  1.30
# 2        6.812500          23.0          8.0                  0.60
# 3       11.888889          37.0         34.0                  1.15
# 4       18.000000          51.0          8.0                  0.60
#
#    maximum AtomicRadius  ...  mean NsValence  avg_dev NsValence  \
# 0                  1.45  ...        1.750000           0.375000
# 1                  1.45  ...        2.000000           0.000000
# 2                  1.45  ...        1.562500           0.492188
# 3                  2.60  ...        1.833333           0.277778
# 4                  1.85  ...        2.000000           0.000000
#
#    range NsValence  mode NsValence  minimum ZungerPP-r_sigma  \
# 0              1.0             2.0                     1.285
# 1              0.0             2.0                     1.765
# 2              1.0             2.0                     0.465
# 3              1.0             2.0                     1.285
# 4              0.0             2.0                     0.465
#
#    maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  avg_dev ZungerPP-r_sigma  \
# 0                      2.04               1.622500                  0.337500
# 1                      2.65               2.060000                  0.393333
# 2                      2.44               1.224375                  0.759375
# 3                      4.31               2.420833                  1.202778
# 4                      4.48               2.147500                  1.166250
#
#    range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   0.755                  1.285
# 1                   0.885                  1.765
# 2                   1.975                  0.465
# 3                   3.025                  1.285
# 4                   4.015                  0.465
#
# [5 rows x 230 columns]

# %%
# 保存
os.makedirs('./Data/train_data', exist_ok=True)
os.makedirs('./Data/test_data', exist_ok=True)
mp_train_set.to_csv('./Data/train_data/mp_train_set.csv', index=False)
mp_test_set.to_csv('./Data/test_data/mp_test_set.csv', index=False)
mp_plus_train_set.to_csv('./Data/train_data/mp_plus_train_set.csv', index=False)
mp_plus_test_set.to_csv('./Data/test_data/mp_plus_test_set.csv', index=False)
exp_train_set.to_csv('./Data/train_data/exp_train_set.csv', index=False)
exp_test_set.to_csv('./Data/test_data/exp_test_set.csv', index=False)
mix_test_set.to_csv('./Data/test_data/mix_test_set.csv', index=False)
