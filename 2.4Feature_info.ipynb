# %% [markdown]
# # Feature Information

# %%
import os
import pandas as pd

# %%
current_path = os.getcwd()
current_path
# Out:
# '/workspaces/Bg_pre3'

# %%
feat_df = pd.read_csv(os.path.join(current_path, './metrics/feature_importance/RFE/feature_importance.csv'))
feat_df.head()
# Out:
#                      Feature  Importance
# 0  maximum Electronegativity    0.044397
# 1              mean MeltingT    0.040305
# 2        mode CovalentRadius    0.035606
# 3     minimum CovalentRadius    0.027777
# 4             range MeltingT    0.023185

# %%
# 计算相同特征的所有不同统计量的平均值
feat_df['feature'] = feat_df['Feature'].apply(lambda x: x.split(' ')[1])
feat_df['statistic'] = feat_df['Feature'].apply(lambda x: x.split(' ')[0])
feat_df.drop(columns=['Feature'], inplace=True)
feat_df
# Out:
#     Importance            feature statistic
# 0     0.044397  Electronegativity   maximum
# 1     0.040305           MeltingT      mean
# 2     0.035606     CovalentRadius      mode
# 3     0.027777     CovalentRadius   minimum
# 4     0.023185           MeltingT     range
# ..         ...                ...       ...
# 72    0.005640           GSmagmom   avg_dev
# 73    0.005535  Electronegativity   minimum
# 74    0.005362     CovalentRadius   maximum
# 75    0.004522          NfValence   avg_dev
# 76    0.004520          NfValence      mean
#
# [77 rows x 3 columns]

# %%
feat_df['importance'] = feat_df['Importance']
feat_df.drop(columns=['Importance'], inplace=True)
feat_df
# Out:
#               feature statistic  importance
# 0   Electronegativity   maximum    0.044397
# 1            MeltingT      mean    0.040305
# 2      CovalentRadius      mode    0.035606
# 3      CovalentRadius   minimum    0.027777
# 4            MeltingT     range    0.023185
# ..                ...       ...         ...
# 72           GSmagmom   avg_dev    0.005640
# 73  Electronegativity   minimum    0.005535
# 74     CovalentRadius   maximum    0.005362
# 75          NfValence   avg_dev    0.004522
# 76          NfValence      mean    0.004520
#
# [77 rows x 3 columns]

# %%
feat_df.groupby(['feature']).agg({'importance': 'sum'}).reset_index().sort_values(by='importance', ascending=False).reset_index(drop=True).head(20)
# Out:
#               feature  importance
# 0            MeltingT    0.119921
# 1   Electronegativity    0.115597
# 2      CovalentRadius    0.106191
# 3     MendeleevNumber    0.061318
# 4              Number    0.055699
# 5         GSvolume_pa    0.055077
# 6           NUnfilled    0.054526
# 7        AtomicWeight    0.047747
# 8            NValence    0.046909
# 9           NdValence    0.043810
# 10   SpaceGroupNumber    0.039544
# 11             Column    0.037203
# 12         NpUnfilled    0.035060
# 13          NpValence    0.034010
# 14          GSbandgap    0.031070
# 15                Row    0.028184
# 16         NdUnfilled    0.024249
# 17         NfUnfilled    0.019363
# 18          NsValence    0.012592
# 19         NsUnfilled    0.011450
