# %% [markdown]
# # Self Learning
#
# 1. see the dft data as unlabeled data, and then we use the xgboost model which trained on exp set to label the dft data.
# 2. discard items that differ significantly(**Δ>1**) between exp model prediction and dft calculation.
# 3. use the labeled dft data and exp data together to train model and then label the dft data again.
# 4. Repeat the above steps.

# %%
import os
import sys
import pandas as pd
import numpy as np
np.random.seed(42)
current_path = os.getcwd()
current_path
# Out:
# 'c:\\Users\\Fortyfour\\Desktop\\graduation_design\\New_Scripts'

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
# 
FIG_SHOW = False

# %%
# To import the custom module from a specific path
sys.path.insert(0, os.path.join(current_path, '../'))
# Importing the custom module
from Utools.SingleModel import SingleModel

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'mp_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mp_test_set.csv'))
# exp data
exp_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'exp_train_set.csv'))
exp_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'exp_test_set.csv'))
# mix test data
mix_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mix_test_set.csv'))

dft_train_X = dft_train.drop(columns=['composition', 'band_gap'])
dft_train_y = dft_train['band_gap']
exp_train_X = exp_train.drop(columns=['composition', 'band_gap'])
exp_train_y = exp_train['band_gap']
dft_test_X = dft_test.drop(columns=['composition', 'band_gap'])
dft_test_y = dft_test['band_gap']
exp_test_X = exp_test.drop(columns=['composition', 'band_gap'])
exp_test_y = exp_test['band_gap']

mix_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mix_test_set.csv'))
mixed_test_X = mix_test.drop(columns=['composition', 'band_gap'])
mixed_test_y = mix_test['band_gap']

# %%
dft_train_X.shape, exp_train_X.shape, mixed_test_X.shape, mixed_test_y.shape
# Out:
# ((4412, 132), (1595, 132), (837, 132), (837,))

# %%
from xgboost import XGBRegressor
from sklearn.base import clone

# %%
xgb = XGBRegressor(learning_rate=0.1, max_depth=5, n_estimators=500,
    colsample_bytree=0.7, subsample=0.9, reg_lambda=0.5, alpha=0.5,
    objective='reg:squarederror', random_state=RANDOM_SEED, n_jobs=-1)
exp_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
exp_model.train(exp_train_X, exp_train_y)
# Out:
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   0.9s
# Model training completed!

# %%
# 1. total dft train data 
self_learn_model = exp_model
eventually_model = None
# 
LARGE_ERROR = 0.5
SMALL_ERROR_RATE = 0.95
EXP_RATIO = 0.5
# track
iteration_metrics = []  

for i in range(100):
    pred_y = self_learn_model.predict(dft_train_X)

    # discard the samples with large error
    # get the samples with small error  
    small_error_index = (np.abs(pred_y - dft_train_y) <= LARGE_ERROR)
    small_error_X = dft_train_X[small_error_index]
    # 
    small_error_y = (pred_y[small_error_index]*EXP_RATIO) + (dft_train_y[small_error_index]*(1-EXP_RATIO))

    # 
    if small_error_X.shape[0] > SMALL_ERROR_RATE*len(dft_train_X):
        print('The number of small error samples is greater than the threshold.')
        eventually_model = self_learn_model
        break
    # log
    print(f'[ Iteration {i} ]: ')
    print(f'small error samples: {small_error_X.shape[0]}')
    # save metrics
    test_metrics = self_learn_model.evaluate(mixed_test_X, mixed_test_y, fig_show=False)
    iteration_metrics.append({
        'iteration': i,
        'small_error_samples': small_error_X.shape[0],
        'test_r2': test_metrics['r2'],
        'test_rmse': test_metrics['rmse']
    })

    # early stopping
    if i > 0 and iteration_metrics[-1]['test_rmse'] >= iteration_metrics[-2]['test_rmse']:
        consecutive_no_improvement += 1
    else:
        consecutive_no_improvement = 0

    if consecutive_no_improvement >= 3:
        print(f"Early stopping at iteration {i} due to no improvement")
        eventually_model = self_learn_model
        break

    # train the model on the small error samples and exp samples
    train_X = pd.concat([small_error_X, exp_train_X], axis=0, ignore_index=True)
    train_y = pd.concat([small_error_y, exp_train_y], axis=0, ignore_index=True)

    self_learn_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
    self_learn_model.train(train_X, train_y)

if eventually_model is None:
    eventually_model = self_learn_model
# Out:
# [ Iteration 0 ]:
# small error samples: 1979
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.2726 RMSE: 0.6828 MAE: 0.5053 MAPE: 166.7575%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.1s
# Model training completed!
# [ Iteration 1 ]:
# small error samples: 2272
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3433 RMSE: 0.6487 MAE: 0.4757 MAPE: 155.8931%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 2 ]:
# small error samples: 2453
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3491 RMSE: 0.6458 MAE: 0.4707 MAPE: 152.3164%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 3 ]:
# small error samples: 2581
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3773 RMSE: 0.6317 MAE: 0.4574 MAPE: 144.7363%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 4 ]:
# small error samples: 2662
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3794 RMSE: 0.6306 MAE: 0.4586 MAPE: 141.5803%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 5 ]:
# small error samples: 2710
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3939 RMSE: 0.6232 MAE: 0.4525 MAPE: 137.7397%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 6 ]:
# small error samples: 2770
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4067 RMSE: 0.6166 MAE: 0.4457 MAPE: 127.8017%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 7 ]:
# small error samples: 2818
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.3945 RMSE: 0.6229 MAE: 0.4520 MAPE: 133.4594%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 8 ]:
# small error samples: 2856
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4101 RMSE: 0.6149 MAE: 0.4446 MAPE: 129.6081%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 9 ]:
# small error samples: 2887
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4047 RMSE: 0.6177 MAE: 0.4457 MAPE: 127.0885%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 10 ]:
# small error samples: 2913
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4187 RMSE: 0.6103 MAE: 0.4376 MAPE: 119.9815%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 11 ]:
# small error samples: 2932
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4134 RMSE: 0.6131 MAE: 0.4404 MAPE: 120.7515%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 12 ]:
# small error samples: 2952
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4157 RMSE: 0.6119 MAE: 0.4405 MAPE: 120.4294%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 13 ]:
# small error samples: 2976
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4063 RMSE: 0.6168 MAE: 0.4425 MAPE: 121.8666%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 14 ]:
# small error samples: 2995
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4037 RMSE: 0.6182 MAE: 0.4403 MAPE: 123.7935%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 15 ]:
# small error samples: 3011
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4118 RMSE: 0.6139 MAE: 0.4414 MAPE: 119.1352%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 16 ]:
# small error samples: 3025
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4165 RMSE: 0.6115 MAE: 0.4395 MAPE: 115.0625%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 17 ]:
# small error samples: 3036
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4245 RMSE: 0.6073 MAE: 0.4313 MAPE: 117.7445%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 18 ]:
# small error samples: 3044
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4179 RMSE: 0.6108 MAE: 0.4350 MAPE: 113.1882%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 19 ]:
# small error samples: 3057
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4165 RMSE: 0.6115 MAE: 0.4363 MAPE: 118.7907%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 20 ]:
# small error samples: 3064
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4193 RMSE: 0.6100 MAE: 0.4380 MAPE: 119.8797%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 21 ]:
# small error samples: 3074
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4220 RMSE: 0.6086 MAE: 0.4377 MAPE: 118.8543%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 22 ]:
# small error samples: 3089
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4236 RMSE: 0.6078 MAE: 0.4318 MAPE: 117.8978%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 23 ]:
# small error samples: 3096
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4181 RMSE: 0.6107 MAE: 0.4338 MAPE: 111.9611%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 24 ]:
# small error samples: 3106
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4260 RMSE: 0.6065 MAE: 0.4299 MAPE: 113.2471%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 25 ]:
# small error samples: 3109
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4287 RMSE: 0.6051 MAE: 0.4288 MAPE: 112.0128%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 26 ]:
# small error samples: 3126
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4238 RMSE: 0.6077 MAE: 0.4338 MAPE: 114.7266%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 27 ]:
# small error samples: 3132
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4286 RMSE: 0.6051 MAE: 0.4298 MAPE: 114.6698%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 28 ]:
# small error samples: 3140
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4164 RMSE: 0.6115 MAE: 0.4365 MAPE: 116.1456%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 29 ]:
# small error samples: 3150
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4228 RMSE: 0.6082 MAE: 0.4323 MAPE: 116.0033%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 30 ]:
# small error samples: 3155
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4190 RMSE: 0.6102 MAE: 0.4352 MAPE: 112.7164%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 31 ]:
# small error samples: 3158
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4302 RMSE: 0.6043 MAE: 0.4287 MAPE: 112.5230%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 32 ]:
# small error samples: 3159
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4299 RMSE: 0.6044 MAE: 0.4285 MAPE: 108.7189%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 33 ]:
# small error samples: 3164
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4338 RMSE: 0.6024 MAE: 0.4289 MAPE: 107.0639%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 34 ]:
# small error samples: 3170
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4273 RMSE: 0.6058 MAE: 0.4285 MAPE: 106.4000%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 35 ]:
# small error samples: 3174
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4247 RMSE: 0.6072 MAE: 0.4313 MAPE: 108.3214%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 36 ]:
# small error samples: 3182
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4388 RMSE: 0.5997 MAE: 0.4267 MAPE: 101.5477%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 37 ]:
# small error samples: 3185
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4231 RMSE: 0.6080 MAE: 0.4351 MAPE: 101.4645%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 38 ]:
# small error samples: 3186
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4336 RMSE: 0.6025 MAE: 0.4283 MAPE: 102.5768%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 39 ]:
# small error samples: 3189
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4346 RMSE: 0.6020 MAE: 0.4283 MAPE: 101.2141%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!
# [ Iteration 40 ]:
# small error samples: 3189
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4372 RMSE: 0.6005 MAE: 0.4241 MAPE: 98.9057%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Model training completed!
# [ Iteration 41 ]:
# small error samples: 3192
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4502 RMSE: 0.5936 MAE: 0.4189 MAPE: 97.6203%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 42 ]:
# small error samples: 3196
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4349 RMSE: 0.6018 MAE: 0.4300 MAPE: 101.3804%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 43 ]:
# small error samples: 3197
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4340 RMSE: 0.6023 MAE: 0.4304 MAPE: 100.2180%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 44 ]:
# small error samples: 3200
#
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4277 RMSE: 0.6056 MAE: 0.4332 MAPE: 101.6693%
# Early stopping at iteration 44 due to no improvement

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5), dpi=300)
plt.subplot(1, 2, 1)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['small_error_samples'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Small Error Samples')
plt.subplot(1, 2, 2)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['test_rmse'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Test RMSE')
plt.tight_layout()
# plt.savefig(os.path.join(file_path, 'iteration_metrics.png'))

# %%
# 
MODEL_NAME = 'Self Learning XGBoost'
# record model metrics
model_metrics = pd.DataFrame(columns=['Model', 'Error_Type', 'Train_set', 'Test_set', 'R²', 'RMSE', 'MAE'])
# Train the model on mixed data
print("#" * 100)
print(f"[DFT - {MODEL_NAME}] Training {MODEL_NAME} on Mix data:")
print("-" * 100)

model = eventually_model

# evaluate on the train set
print(f"[Train_error] Evaluating {MODEL_NAME} on train set:")
metrics = model.evaluate(train_X, train_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Train',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the dft test set
print(f"[Test MIX -> DFT] Evaluating {MODEL_NAME} on DFT test set:")

metrics = model.evaluate(dft_test_X, dft_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'dft',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# evaluate on the exp test set
print(f"[Test MIX -> EXP] Evaluating {MODEL_NAME} on EXP test set:")
metrics = model.evaluate(exp_test_X, exp_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'exp',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the mixed test set
print(f"[Test MIX -> MIX] Evaluating {MODEL_NAME} on mixed test set:")
metrics = model.evaluate(mixed_test_X, mixed_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,    
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# save the model metrics to a csv file
model_metrics.to_csv(os.path.join('./metrics', 'self_learning_metrics.csv'), index=False)
model_metrics
# Out:
# ####################################################################################################
# [DFT - Self Learning XGBoost] Training Self Learning XGBoost on Mix data:
# ----------------------------------------------------------------------------------------------------
# [Train_error] Evaluating Self Learning XGBoost on train set:
# Model Evaluation Results:
# Test set size: 4792
# Test set: R²: 0.9840 RMSE: 0.0952 MAE: 0.0703 MAPE: 7.0794%
# [Test MIX -> DFT] Evaluating Self Learning XGBoost on DFT test set:
# Model Evaluation Results:
# Test set size: 1108
# Test set: R²: 0.3619 RMSE: 0.6801 MAE: 0.4865 MAPE: 347.9975%
# [Test MIX -> EXP] Evaluating Self Learning XGBoost on EXP test set:
# Model Evaluation Results:
# Test set size: 335
# Test set: R²: 0.6478 RMSE: 0.4447 MAE: 0.3249 MAPE: 28.1727%
# [Test MIX -> MIX] Evaluating Self Learning XGBoost on mixed test set:
# Model Evaluation Results:
# Test set size: 837
# Test set: R²: 0.4277 RMSE: 0.6056 MAE: 0.4332 MAPE: 101.6693%
#                    Model Error_Type Train_set Test_set        R²      RMSE  \
# 0  Self Learning XGBoost      Train       mix      mix  0.984021  0.095213
# 1  Self Learning XGBoost       Test       mix      dft  0.361948  0.680053
# 2  Self Learning XGBoost       Test       mix      exp  0.647773  0.444650
# 3  Self Learning XGBoost       Test       mix      mix  0.427714  0.605592
#
#         MAE
# 0  0.070260
# 1  0.486507
# 2  0.324907
# 3  0.433218

# %% [markdown]
# **Compare to direct mix:**
# - the self-learning model has a better performance on the **exp test set**,
# - but the performance on the dft test set is not as good as the direct mix model.

# %% [markdown]
# - Sampled dft train data model is not good as the total dft train data model.
