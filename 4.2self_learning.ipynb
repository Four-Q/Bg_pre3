# %% [markdown]
# # Self Learning
#
# 1. see the dft data as unlabeled data, and then we use the xgboost model which trained on exp set to label the dft data.
# 2. discard items that differ significantly(**Δ>1**) between exp model prediction and dft calculation.
# 3. use the labeled dft data and exp data together to train model and then label the dft data again.
# 4. Repeat the above steps.

# %%
import os
import sys
import pandas as pd
import numpy as np
np.random.seed(42)
current_path = os.getcwd()
current_path
# Out:
# '/workspaces/Bg_pre3'

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
# 
FIG_SHOW = False

# %%
# To import the custom module from a specific path
sys.path.insert(0, os.path.join(current_path, '../'))
# Importing the custom module
from Utools.SingleModel import SingleModel

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'mp_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mp_test_set.csv'))
# exp data
exp_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'exp_train_set.csv'))
exp_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'exp_test_set.csv'))
# mix test data
mix_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mix_test_set.csv'))

dft_train_X = dft_train.drop(columns=['composition', 'band_gap'])
dft_train_y = dft_train['band_gap']
exp_train_X = exp_train.drop(columns=['composition', 'band_gap'])
exp_train_y = exp_train['band_gap']
dft_test_X = dft_test.drop(columns=['composition', 'band_gap'])
dft_test_y = dft_test['band_gap']
exp_test_X = exp_test.drop(columns=['composition', 'band_gap'])
exp_test_y = exp_test['band_gap']

mix_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mix_test_set.csv'))
mixed_test_X = mix_test.drop(columns=['composition', 'band_gap'])
mixed_test_y = mix_test['band_gap']

# %%
dft_train_X.shape, exp_train_X.shape, mixed_test_X.shape, mixed_test_y.shape
# Out:
# ((8275, 77), (2545, 77), (1170, 77), (1170,))

# %%
from xgboost import XGBRegressor
from sklearn.base import clone

# %%
xgb = XGBRegressor(learning_rate=0.1, max_depth=5, n_estimators=500,
    colsample_bytree=0.7, subsample=0.9, reg_lambda=0.5, alpha=0.5,
    objective='reg:squarederror', random_state=RANDOM_SEED, n_jobs=-1)
exp_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
exp_model.train(exp_train_X, exp_train_y)
# Out:
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   4.7s
# Model training completed!

# %%
# 1. total dft train data 
self_learn_model = exp_model
eventually_model = None
# 
LARGE_ERROR = 0.5
SMALL_ERROR_RATE = 0.95
EXP_RATIO = 0.5
# track
iteration_metrics = []  

for i in range(100):
    pred_y = self_learn_model.predict(dft_train_X)

    # discard the samples with large error
    # get the samples with small error  
    small_error_index = (np.abs(pred_y - dft_train_y) <= LARGE_ERROR)
    small_error_X = dft_train_X[small_error_index]
    
    ############KEY########################
    small_error_y = (pred_y[small_error_index]*EXP_RATIO) + (dft_train_y[small_error_index]*(1-EXP_RATIO))

    # 
    if small_error_X.shape[0] > SMALL_ERROR_RATE*len(dft_train_X):
        print('The number of small error samples is greater than the threshold.')
        eventually_model = self_learn_model
        break
    # log
    print(f'[ Iteration {i} ]: ')
    print(f'small error samples: {small_error_X.shape[0]}')
    # save metrics
    test_metrics = self_learn_model.evaluate(mixed_test_X, mixed_test_y, fig_show=False)
    iteration_metrics.append({
        'iteration': i,
        'small_error_samples': small_error_X.shape[0],
        'test_r2': test_metrics['r2'],
        'test_rmse': test_metrics['rmse']
    })

    # early stopping
    if i > 0 and iteration_metrics[-1]['test_rmse'] >= iteration_metrics[-2]['test_rmse']:
        consecutive_no_improvement += 1
    else:
        consecutive_no_improvement = 0

    if consecutive_no_improvement >= 3:
        print(f"Early stopping at iteration {i} due to no improvement")
        eventually_model = self_learn_model
        break

    # train the model on the small error samples and exp samples
    train_X = pd.concat([small_error_X, exp_train_X], axis=0, ignore_index=True)
    train_y = pd.concat([small_error_y, exp_train_y], axis=0, ignore_index=True)

    self_learn_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
    self_learn_model.train(train_X, train_y)

if eventually_model is None:
    eventually_model = self_learn_model
# Out:
# [ Iteration 0 ]:
# small error samples: 3712
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.3084 RMSE: 0.6924 MAE: 0.4950 MAPE: 942.5984%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 1 ]:
# small error samples: 4302
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.3565 RMSE: 0.6679 MAE: 0.4689 MAPE: 938.4904%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 2 ]:
# small error samples: 4598
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.3759 RMSE: 0.6577 MAE: 0.4573 MAPE: 724.3405%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 3 ]:
# small error samples: 4775
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.3948 RMSE: 0.6477 MAE: 0.4434 MAPE: 683.9337%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 4 ]:
# small error samples: 4899
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.3996 RMSE: 0.6451 MAE: 0.4446 MAPE: 629.1893%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 5 ]:
# small error samples: 5028
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4054 RMSE: 0.6420 MAE: 0.4394 MAPE: 603.0374%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 6 ]:
# small error samples: 5099
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4159 RMSE: 0.6363 MAE: 0.4337 MAPE: 613.6631%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 7 ]:
# small error samples: 5185
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4132 RMSE: 0.6378 MAE: 0.4342 MAPE: 628.0089%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 8 ]:
# small error samples: 5245
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4201 RMSE: 0.6340 MAE: 0.4298 MAPE: 602.2852%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 9 ]:
# small error samples: 5311
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4296 RMSE: 0.6288 MAE: 0.4302 MAPE: 599.7810%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 10 ]:
# small error samples: 5361
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4274 RMSE: 0.6300 MAE: 0.4266 MAPE: 596.9627%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 11 ]:
# small error samples: 5407
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4283 RMSE: 0.6295 MAE: 0.4250 MAPE: 583.6610%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 12 ]:
# small error samples: 5437
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4270 RMSE: 0.6302 MAE: 0.4260 MAPE: 586.9916%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 13 ]:
# small error samples: 5457
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4372 RMSE: 0.6246 MAE: 0.4235 MAPE: 637.8120%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4611 RMSE: 0.6112 MAE: 0.4147 MAPE: 583.2486%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 85 ]:
# small error samples: 5930
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4634 RMSE: 0.6099 MAE: 0.4126 MAPE: 562.8998%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 86 ]:
# small error samples: 5930
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4633 RMSE: 0.6099 MAE: 0.4116 MAPE: 567.4921%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 87 ]:
# small error samples: 5930
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4571 RMSE: 0.6134 MAE: 0.4139 MAPE: 564.3043%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 88 ]:
# small error samples: 5929
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4613 RMSE: 0.6111 MAE: 0.4126 MAPE: 598.9318%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 89 ]:
# small error samples: 5930
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4583 RMSE: 0.6127 MAE: 0.4156 MAPE: 566.5527%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 90 ]:
# small error samples: 5927
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4582 RMSE: 0.6128 MAE: 0.4129 MAPE: 629.2271%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 91 ]:
# small error samples: 5929
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4635 RMSE: 0.6098 MAE: 0.4114 MAPE: 587.3146%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 92 ]:
# small error samples: 5931
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4609 RMSE: 0.6113 MAE: 0.4099 MAPE: 579.5160%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 93 ]:
# small error samples: 5932
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4659 RMSE: 0.6084 MAE: 0.4083 MAPE: 618.6633%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 94 ]:
# small error samples: 5934
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4677 RMSE: 0.6074 MAE: 0.4084 MAPE: 633.7322%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 95 ]:
# small error samples: 5933
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4626 RMSE: 0.6103 MAE: 0.4114 MAPE: 613.7561%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 96 ]:
# small error samples: 5935
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4597 RMSE: 0.6119 MAE: 0.4141 MAPE: 572.6540%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.4s
# Model training completed!
# [ Iteration 97 ]:
# small error samples: 5936
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4713 RMSE: 0.6053 MAE: 0.4074 MAPE: 624.7529%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!
# [ Iteration 98 ]:
# small error samples: 5938
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4697 RMSE: 0.6063 MAE: 0.4074 MAPE: 598.9195%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 99 ]:
# small error samples: 5938
#
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4723 RMSE: 0.6048 MAE: 0.4085 MAPE: 568.4966%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.5s
# Model training completed!

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5), dpi=300)
plt.subplot(1, 2, 1)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['small_error_samples'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Small Error Samples')
plt.subplot(1, 2, 2)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['test_rmse'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Test RMSE')
plt.tight_layout()
# plt.savefig(os.path.join(file_path, 'iteration_metrics.png'))

# %%
# 
MODEL_NAME = 'Self Learning XGBoost'
# record model metrics
model_metrics = pd.DataFrame(columns=['Model', 'Error_Type', 'Train_set', 'Test_set', 'R²', 'RMSE', 'MAE'])
# Train the model on mixed data
print("#" * 100)
print(f"[DFT - {MODEL_NAME}] Training {MODEL_NAME} on Mix data:")
print("-" * 100)

model = eventually_model

# evaluate on the train set
print(f"[Train_error] Evaluating {MODEL_NAME} on train set:")
metrics = model.evaluate(train_X, train_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Train',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the dft test set
print(f"[Test MIX -> DFT] Evaluating {MODEL_NAME} on DFT test set:")

metrics = model.evaluate(dft_test_X, dft_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'dft',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# evaluate on the exp test set
print(f"[Test MIX -> EXP] Evaluating {MODEL_NAME} on EXP test set:")
metrics = model.evaluate(exp_test_X, exp_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'exp',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the mixed test set
print(f"[Test MIX -> MIX] Evaluating {MODEL_NAME} on mixed test set:")
metrics = model.evaluate(mixed_test_X, mixed_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,    
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# save the model metrics to a csv file
model_metrics.to_csv(os.path.join('./metrics', 'self_learning_metrics.csv'), index=False)
model_metrics
# Out:
# ####################################################################################################
# [DFT - Self Learning XGBoost] Training Self Learning XGBoost on Mix data:
# ----------------------------------------------------------------------------------------------------
# [Train_error] Evaluating Self Learning XGBoost on train set:
# Model Evaluation Results:
# Test set size: 8483
# Test set: R²: 0.9767 RMSE: 0.1191 MAE: 0.0894 MAPE: 12.5554%
# [Test MIX -> DFT] Evaluating Self Learning XGBoost on DFT test set:
# Model Evaluation Results:
# Test set size: 2067
# Test set: R²: 0.2818 RMSE: 0.7254 MAE: 0.5097 MAPE: 1200.3889%
# [Test MIX -> EXP] Evaluating Self Learning XGBoost on EXP test set:
# Model Evaluation Results:
# Test set size: 585
# Test set: R²: 0.7418 RMSE: 0.4027 MAE: 0.2854 MAPE: 47.4588%
# [Test MIX -> MIX] Evaluating Self Learning XGBoost on mixed test set:
# Model Evaluation Results:
# Test set size: 1170
# Test set: R²: 0.4668 RMSE: 0.6079 MAE: 0.4088 MAPE: 603.2812%
#                    Model Error_Type Train_set Test_set        R²      RMSE  \
# 0  Self Learning XGBoost      Train       mix      mix  0.976724  0.119099
# 1  Self Learning XGBoost       Test       mix      dft  0.281830  0.725373
# 2  Self Learning XGBoost       Test       mix      exp  0.741823  0.402729
# 3  Self Learning XGBoost       Test       mix      mix  0.466812  0.607926
#
#         MAE
# 0  0.089443
# 1  0.509694
# 2  0.285446
# 3  0.408813

# %% [markdown]
# **Compare to direct mix:**
# - the self-learning model has a better performance on the **exp test set**,
# - but the performance on the dft test set is not as good as the direct mix model.

# %% [markdown]
# - Sampled dft train data model is not good as the total dft train data model.
