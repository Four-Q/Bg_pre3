# %% [markdown]
# # Self Learning
#
# 1. see the dft data as unlabeled data, and then we use the xgboost model which trained on exp set to label the dft data.
# 2. discard items that differ significantly(**Δ>1**) between exp model prediction and dft calculation.
# 3. use the labeled dft data and exp data together to train model and then label the dft data again.
# 4. Repeat the above steps.

# %%
import os
import sys
import pandas as pd
import numpy as np
np.random.seed(42)
current_path = os.getcwd()
current_path
# Out:
# '/workspaces/Bg_pre2'

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
# 
FIG_SHOW = False

# %%
# To import the custom module from a specific path
sys.path.insert(0, os.path.join(current_path, '../'))
# Importing the custom module
from Utools.SingleModel import SingleModel

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'mp_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mp_test_set.csv'))
# exp data
exp_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'exp_train_set.csv'))
exp_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'exp_test_set.csv'))
# mix test data
mix_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mix_test_set.csv'))

dft_train_X = dft_train.drop(columns=['composition', 'band_gap'])
dft_train_y = dft_train['band_gap']
exp_train_X = exp_train.drop(columns=['composition', 'band_gap'])
exp_train_y = exp_train['band_gap']
dft_test_X = dft_test.drop(columns=['composition', 'band_gap'])
dft_test_y = dft_test['band_gap']
exp_test_X = exp_test.drop(columns=['composition', 'band_gap'])
exp_test_y = exp_test['band_gap']

mix_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mix_test_set.csv'))
mixed_test_X = mix_test.drop(columns=['composition', 'band_gap'])
mixed_test_y = mix_test['band_gap']

# %%
dft_train_X.shape, exp_train_X.shape, mixed_test_X.shape, mixed_test_y.shape
# Out:
# ((8268, 132), (2544, 132), (1172, 132), (1172,))

# %%
from xgboost import XGBRegressor
from sklearn.base import clone

# %%
xgb = XGBRegressor(learning_rate=0.1, max_depth=5, n_estimators=500,
    colsample_bytree=0.7, subsample=0.9, reg_lambda=0.5, alpha=0.5,
    objective='reg:squarederror', random_state=RANDOM_SEED, n_jobs=-1)
exp_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
exp_model.train(exp_train_X, exp_train_y)
# Out:
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.3s
# Model training completed!

# %%
# 1. total dft train data 
self_learn_model = exp_model
eventually_model = None
# 
LARGE_ERROR = 0.5
SMALL_ERROR_RATE = 0.95
EXP_RATIO = 0.5
# track
iteration_metrics = []  

for i in range(100):
    pred_y = self_learn_model.predict(dft_train_X)

    # discard the samples with large error
    # get the samples with small error  
    small_error_index = (np.abs(pred_y - dft_train_y) <= LARGE_ERROR)
    small_error_X = dft_train_X[small_error_index]
    
    ############KEY########################
    small_error_y = (pred_y[small_error_index]*EXP_RATIO) + (dft_train_y[small_error_index]*(1-EXP_RATIO))

    # 
    if small_error_X.shape[0] > SMALL_ERROR_RATE*len(dft_train_X):
        print('The number of small error samples is greater than the threshold.')
        eventually_model = self_learn_model
        break
    # log
    print(f'[ Iteration {i} ]: ')
    print(f'small error samples: {small_error_X.shape[0]}')
    # save metrics
    test_metrics = self_learn_model.evaluate(mixed_test_X, mixed_test_y, fig_show=False)
    iteration_metrics.append({
        'iteration': i,
        'small_error_samples': small_error_X.shape[0],
        'test_r2': test_metrics['r2'],
        'test_rmse': test_metrics['rmse']
    })

    # early stopping
    if i > 0 and iteration_metrics[-1]['test_rmse'] >= iteration_metrics[-2]['test_rmse']:
        consecutive_no_improvement += 1
    else:
        consecutive_no_improvement = 0

    if consecutive_no_improvement >= 3:
        print(f"Early stopping at iteration {i} due to no improvement")
        eventually_model = self_learn_model
        break

    # train the model on the small error samples and exp samples
    train_X = pd.concat([small_error_X, exp_train_X], axis=0, ignore_index=True)
    train_y = pd.concat([small_error_y, exp_train_y], axis=0, ignore_index=True)

    self_learn_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
    self_learn_model.train(train_X, train_y)

if eventually_model is None:
    eventually_model = self_learn_model
# Out:
# [ Iteration 0 ]:
# small error samples: 3706
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.2870 RMSE: 0.6897 MAE: 0.4871 MAPE: 384.6546%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.6s
# Model training completed!
# [ Iteration 1 ]:
# small error samples: 4255
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.3557 RMSE: 0.6557 MAE: 0.4581 MAPE: 356.4379%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 2 ]:
# small error samples: 4549
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.3762 RMSE: 0.6452 MAE: 0.4457 MAPE: 314.8215%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 3 ]:
# small error samples: 4745
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.3919 RMSE: 0.6370 MAE: 0.4369 MAPE: 290.5662%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 4 ]:
# small error samples: 4877
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.3976 RMSE: 0.6340 MAE: 0.4332 MAPE: 285.6998%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 5 ]:
# small error samples: 4974
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4060 RMSE: 0.6295 MAE: 0.4279 MAPE: 270.6426%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 6 ]:
# small error samples: 5070
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4209 RMSE: 0.6216 MAE: 0.4235 MAPE: 263.7388%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.9s
# Model training completed!
# [ Iteration 7 ]:
# small error samples: 5156
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4290 RMSE: 0.6172 MAE: 0.4204 MAPE: 252.2546%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 8 ]:
# small error samples: 5225
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4240 RMSE: 0.6199 MAE: 0.4225 MAPE: 268.7511%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 9 ]:
# small error samples: 5272
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4391 RMSE: 0.6118 MAE: 0.4136 MAPE: 259.7691%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 10 ]:
# small error samples: 5318
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4391 RMSE: 0.6118 MAE: 0.4163 MAPE: 274.0392%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 11 ]:
# small error samples: 5347
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4301 RMSE: 0.6167 MAE: 0.4193 MAPE: 275.2401%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.1s
# Model training completed!
# [ Iteration 12 ]:
# small error samples: 5369
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4436 RMSE: 0.6093 MAE: 0.4139 MAPE: 281.3830%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 13 ]:
# small error samples: 5393
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4429 RMSE: 0.6097 MAE: 0.4108 MAPE: 287.3481%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 14 ]:
# small error samples: 5411
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4452 RMSE: 0.6084 MAE: 0.4105 MAPE: 274.1893%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 15 ]:
# small error samples: 5431
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4480 RMSE: 0.6069 MAE: 0.4120 MAPE: 281.5034%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   3.6s
# Model training completed!
# [ Iteration 16 ]:
# small error samples: 5453
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.

# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 61 ]:
# small error samples: 5846
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4837 RMSE: 0.5869 MAE: 0.3977 MAPE: 274.8329%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 62 ]:
# small error samples: 5843
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4818 RMSE: 0.5880 MAE: 0.3986 MAPE: 273.6158%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.6s
# Model training completed!
# [ Iteration 63 ]:
# small error samples: 5844
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4886 RMSE: 0.5842 MAE: 0.3968 MAPE: 256.8195%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 64 ]:
# small error samples: 5841
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4886 RMSE: 0.5841 MAE: 0.3952 MAPE: 272.7922%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 65 ]:
# small error samples: 5840
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4911 RMSE: 0.5827 MAE: 0.3943 MAPE: 271.7030%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.9s
# Model training completed!
# [ Iteration 66 ]:
# small error samples: 5844
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4802 RMSE: 0.5889 MAE: 0.3965 MAPE: 272.3837%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 67 ]:
# small error samples: 5846
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4856 RMSE: 0.5859 MAE: 0.3974 MAPE: 258.5866%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 68 ]:
# small error samples: 5850
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4816 RMSE: 0.5881 MAE: 0.3996 MAPE: 269.9527%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 69 ]:
# small error samples: 5852
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4837 RMSE: 0.5869 MAE: 0.3957 MAPE: 273.0565%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 70 ]:
# small error samples: 5854
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4769 RMSE: 0.5908 MAE: 0.3978 MAPE: 284.9091%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.0s
# Model training completed!
# [ Iteration 71 ]:
# small error samples: 5858
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4808 RMSE: 0.5886 MAE: 0.3978 MAPE: 279.4696%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 72 ]:
# small error samples: 5858
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4867 RMSE: 0.5852 MAE: 0.3946 MAPE: 256.0227%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.7s
# Model training completed!
# [ Iteration 73 ]:
# small error samples: 5853
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4856 RMSE: 0.5859 MAE: 0.3950 MAPE: 263.7192%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 74 ]:
# small error samples: 5858
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4821 RMSE: 0.5878 MAE: 0.3947 MAPE: 276.4004%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.8s
# Model training completed!
# [ Iteration 75 ]:
# small error samples: 5859
#
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4815 RMSE: 0.5882 MAE: 0.3985 MAPE: 276.0789%
# Early stopping at iteration 75 due to no improvement

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5), dpi=300)
plt.subplot(1, 2, 1)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['small_error_samples'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Small Error Samples')
plt.subplot(1, 2, 2)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['test_rmse'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Test RMSE')
plt.tight_layout()
# plt.savefig(os.path.join(file_path, 'iteration_metrics.png'))

# %%
# 
MODEL_NAME = 'Self Learning XGBoost'
# record model metrics
model_metrics = pd.DataFrame(columns=['Model', 'Error_Type', 'Train_set', 'Test_set', 'R²', 'RMSE', 'MAE'])
# Train the model on mixed data
print("#" * 100)
print(f"[DFT - {MODEL_NAME}] Training {MODEL_NAME} on Mix data:")
print("-" * 100)

model = eventually_model

# evaluate on the train set
print(f"[Train_error] Evaluating {MODEL_NAME} on train set:")
metrics = model.evaluate(train_X, train_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Train',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the dft test set
print(f"[Test MIX -> DFT] Evaluating {MODEL_NAME} on DFT test set:")

metrics = model.evaluate(dft_test_X, dft_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'dft',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# evaluate on the exp test set
print(f"[Test MIX -> EXP] Evaluating {MODEL_NAME} on EXP test set:")
metrics = model.evaluate(exp_test_X, exp_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'exp',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the mixed test set
print(f"[Test MIX -> MIX] Evaluating {MODEL_NAME} on mixed test set:")
metrics = model.evaluate(mixed_test_X, mixed_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,    
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# save the model metrics to a csv file
model_metrics.to_csv(os.path.join('./metrics', 'self_learning_metrics.csv'), index=False)
model_metrics
# Out:
# ####################################################################################################
# [DFT - Self Learning XGBoost] Training Self Learning XGBoost on Mix data:
# ----------------------------------------------------------------------------------------------------
# [Train_error] Evaluating Self Learning XGBoost on train set:
# Model Evaluation Results:
# Test set size: 8402
# Test set: R²: 0.9774 RMSE: 0.1172 MAE: 0.0876 MAPE: 11.2718%
# [Test MIX -> DFT] Evaluating Self Learning XGBoost on DFT test set:
# Model Evaluation Results:
# Test set size: 2074
# Test set: R²: 0.2759 RMSE: 0.7278 MAE: 0.5123 MAPE: 1226.4291%
# [Test MIX -> EXP] Evaluating Self Learning XGBoost on EXP test set:
# Model Evaluation Results:
# Test set size: 586
# Test set: R²: 0.7382 RMSE: 0.4049 MAE: 0.2965 MAPE: 50.1549%
# [Test MIX -> MIX] Evaluating Self Learning XGBoost on mixed test set:
# Model Evaluation Results:
# Test set size: 1172
# Test set: R²: 0.4815 RMSE: 0.5882 MAE: 0.3985 MAPE: 276.0789%
#                    Model Error_Type Train_set Test_set        R²      RMSE  \
# 0  Self Learning XGBoost      Train       mix      mix  0.977411  0.117248
# 1  Self Learning XGBoost       Test       mix      dft  0.275875  0.727825
# 2  Self Learning XGBoost       Test       mix      exp  0.738197  0.404884
# 3  Self Learning XGBoost       Test       mix      mix  0.481469  0.588211
#
#         MAE
# 0  0.087633
# 1  0.512312
# 2  0.296512
# 3  0.398457

# %% [markdown]
# **Compare to direct mix:**
# - the self-learning model has a better performance on the **exp test set**,
# - but the performance on the dft test set is not as good as the direct mix model.

# %% [markdown]
# - Sampled dft train data model is not good as the total dft train data model.
