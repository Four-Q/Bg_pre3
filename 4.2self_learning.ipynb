# %% [markdown]
# # Self Learning
#
# 1. see the dft data as unlabeled data, and then we use the xgboost model which trained on exp set to label the dft data.
# 2. discard items that differ significantly(**Δ>1**) between exp model prediction and dft calculation.
# 3. use the labeled dft data and exp data together to train model and then label the dft data again.
# 4. Repeat the above steps.

# %%
import os
import sys
import pandas as pd
import numpy as np
np.random.seed(42)
current_path = os.getcwd()
current_path
# Out:
# 'c:\\Users\\Fortyfour\\Desktop\\graduation_design\\New_Scripts\\Bg_pre2'

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
# 
FIG_SHOW = False

# %%
# To import the custom module from a specific path
sys.path.insert(0, os.path.join(current_path, '../'))
# Importing the custom module
from Utools.SingleModel import SingleModel

# %%
# Load data
file_dir = os.path.join(current_path, './Data')
# dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'mp_train_set.csv'))
dft_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mp_test_set.csv'))
# exp data
exp_train = pd.read_csv(os.path.join(file_dir, 'rfe_train_data', 'exp_train_set.csv'))
exp_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'exp_test_set.csv'))
# mix test data
mix_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mix_test_set.csv'))

dft_train_X = dft_train.drop(columns=['composition', 'band_gap'])
dft_train_y = dft_train['band_gap']
exp_train_X = exp_train.drop(columns=['composition', 'band_gap'])
exp_train_y = exp_train['band_gap']
dft_test_X = dft_test.drop(columns=['composition', 'band_gap'])
dft_test_y = dft_test['band_gap']
exp_test_X = exp_test.drop(columns=['composition', 'band_gap'])
exp_test_y = exp_test['band_gap']

mix_test = pd.read_csv(os.path.join(file_dir, 'rfe_test_data', 'mix_test_set.csv'))
mixed_test_X = mix_test.drop(columns=['composition', 'band_gap'])
mixed_test_y = mix_test['band_gap']

# %%
dft_train_X.shape, exp_train_X.shape, mixed_test_X.shape, mixed_test_y.shape
# Out:
# ((7869, 117), (2510, 117), (1198, 117), (1198,))

# %%
from xgboost import XGBRegressor
from sklearn.base import clone

# %%
xgb = XGBRegressor(learning_rate=0.1, max_depth=5, n_estimators=500,
    colsample_bytree=0.7, subsample=0.9, reg_lambda=0.5, alpha=0.5,
    objective='reg:squarederror', random_state=RANDOM_SEED, n_jobs=-1)
exp_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
exp_model.train(exp_train_X, exp_train_y)
# Out:
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.1s
# Model training completed!

# %%
# 1. total dft train data 
self_learn_model = exp_model
eventually_model = None
# 
LARGE_ERROR = 0.5
SMALL_ERROR_RATE = 0.95
EXP_RATIO = 0.5
# track
iteration_metrics = []  

for i in range(100):
    pred_y = self_learn_model.predict(dft_train_X)

    # discard the samples with large error
    # get the samples with small error  
    small_error_index = (np.abs(pred_y - dft_train_y) <= LARGE_ERROR)
    small_error_X = dft_train_X[small_error_index]
    
    ############KEY########################
    small_error_y = (pred_y[small_error_index]*EXP_RATIO) + (dft_train_y[small_error_index]*(1-EXP_RATIO))

    # 
    if small_error_X.shape[0] > SMALL_ERROR_RATE*len(dft_train_X):
        print('The number of small error samples is greater than the threshold.')
        eventually_model = self_learn_model
        break
    # log
    print(f'[ Iteration {i} ]: ')
    print(f'small error samples: {small_error_X.shape[0]}')
    # save metrics
    test_metrics = self_learn_model.evaluate(mixed_test_X, mixed_test_y, fig_show=False)
    iteration_metrics.append({
        'iteration': i,
        'small_error_samples': small_error_X.shape[0],
        'test_r2': test_metrics['r2'],
        'test_rmse': test_metrics['rmse']
    })

    # early stopping
    if i > 0 and iteration_metrics[-1]['test_rmse'] >= iteration_metrics[-2]['test_rmse']:
        consecutive_no_improvement += 1
    else:
        consecutive_no_improvement = 0

    if consecutive_no_improvement >= 3:
        print(f"Early stopping at iteration {i} due to no improvement")
        eventually_model = self_learn_model
        break

    # train the model on the small error samples and exp samples
    train_X = pd.concat([small_error_X, exp_train_X], axis=0, ignore_index=True)
    train_y = pd.concat([small_error_y, exp_train_y], axis=0, ignore_index=True)

    self_learn_model = SingleModel(clone(xgb), random_state=RANDOM_SEED)
    self_learn_model.train(train_X, train_y)

if eventually_model is None:
    eventually_model = self_learn_model
# Out:
# [ Iteration 0 ]:
# small error samples: 3747
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.3638 RMSE: 0.6704 MAE: 0.4887 MAPE: 196.9539%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.1s
# Model training completed!
# [ Iteration 1 ]:
# small error samples: 4343
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4081 RMSE: 0.6467 MAE: 0.4623 MAPE: 183.6009%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 2 ]:
# small error samples: 4642
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4325 RMSE: 0.6332 MAE: 0.4460 MAPE: 175.1369%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.1s
# Model training completed!
# [ Iteration 3 ]:
# small error samples: 4848
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4459 RMSE: 0.6257 MAE: 0.4429 MAPE: 170.0537%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 4 ]:
# small error samples: 4968
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4530 RMSE: 0.6217 MAE: 0.4365 MAPE: 169.8602%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 5 ]:
# small error samples: 5061
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4650 RMSE: 0.6148 MAE: 0.4308 MAPE: 167.9035%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 6 ]:
# small error samples: 5141
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4720 RMSE: 0.6108 MAE: 0.4235 MAPE: 165.4699%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 7 ]:
# small error samples: 5195
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4661 RMSE: 0.6142 MAE: 0.4308 MAPE: 164.5032%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 8 ]:
# small error samples: 5234
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4788 RMSE: 0.6068 MAE: 0.4254 MAPE: 161.9107%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 9 ]:
# small error samples: 5288
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4789 RMSE: 0.6068 MAE: 0.4241 MAPE: 162.4012%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 10 ]:
# small error samples: 5320
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4797 RMSE: 0.6063 MAE: 0.4252 MAPE: 160.9017%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.5s
# Model training completed!
# [ Iteration 11 ]:
# small error samples: 5347
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4772 RMSE: 0.6078 MAE: 0.4214 MAPE: 162.1426%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 12 ]:
# small error samples: 5380
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4864 RMSE: 0.6024 MAE: 0.4191 MAPE: 160.2991%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Model training completed!
# [ Iteration 13 ]:
# small error samples: 5399
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4849 RMSE: 0.6033 MAE: 0.4193 MAPE: 160.9463%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 14 ]:
# small error samples: 5425
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.4860 RMSE: 0.6027 MAE: 0.4177 MAPE: 159.0870%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5138 RMSE: 0.5861 MAE: 0.4006 MAPE: 152.0276%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.9s
# Model training completed!
# [ Iteration 81 ]:
# small error samples: 5783
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5082 RMSE: 0.5895 MAE: 0.4066 MAPE: 150.9837%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 82 ]:
# small error samples: 5786
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5079 RMSE: 0.5897 MAE: 0.4059 MAPE: 153.9509%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 83 ]:
# small error samples: 5788
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5111 RMSE: 0.5878 MAE: 0.4058 MAPE: 155.0240%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 84 ]:
# small error samples: 5791
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5118 RMSE: 0.5873 MAE: 0.4060 MAPE: 150.3473%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.6s
# Model training completed!
# [ Iteration 85 ]:
# small error samples: 5791
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5127 RMSE: 0.5868 MAE: 0.4057 MAPE: 153.0810%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 86 ]:
# small error samples: 5792
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5161 RMSE: 0.5847 MAE: 0.4040 MAPE: 151.6307%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 87 ]:
# small error samples: 5792
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5059 RMSE: 0.5908 MAE: 0.4058 MAPE: 154.1117%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 88 ]:
# small error samples: 5794
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5147 RMSE: 0.5856 MAE: 0.4021 MAPE: 151.8117%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.7s
# Model training completed!
# [ Iteration 89 ]:
# small error samples: 5795
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5142 RMSE: 0.5859 MAE: 0.4080 MAPE: 152.1345%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.5s
# Model training completed!
# [ Iteration 90 ]:
# small error samples: 5795
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5150 RMSE: 0.5854 MAE: 0.4032 MAPE: 150.1042%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 91 ]:
# small error samples: 5796
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5080 RMSE: 0.5896 MAE: 0.4074 MAPE: 155.2352%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.4s
# Model training completed!
# [ Iteration 92 ]:
# small error samples: 5795
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5192 RMSE: 0.5829 MAE: 0.4015 MAPE: 152.3769%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.3s
# Model training completed!
# [ Iteration 93 ]:
# small error samples: 5800
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5149 RMSE: 0.5855 MAE: 0.4045 MAPE: 153.4722%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.9s
# Model training completed!
# [ Iteration 94 ]:
# small error samples: 5800
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5092 RMSE: 0.5889 MAE: 0.4019 MAPE: 151.3119%
# Starting model training...
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.7s
# Model training completed!
# [ Iteration 95 ]:
# small error samples: 5799
#
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5086 RMSE: 0.5892 MAE: 0.4080 MAPE: 151.7525%
# Early stopping at iteration 95 due to no improvement

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5), dpi=300)
plt.subplot(1, 2, 1)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['small_error_samples'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Small Error Samples')
plt.subplot(1, 2, 2)
plt.plot([m['iteration'] for m in iteration_metrics], 
         [m['test_rmse'] for m in iteration_metrics])
plt.xlabel('Iteration')
plt.ylabel('Test RMSE')
plt.tight_layout()
# plt.savefig(os.path.join(file_path, 'iteration_metrics.png'))

# %%
# 
MODEL_NAME = 'Self Learning XGBoost'
# record model metrics
model_metrics = pd.DataFrame(columns=['Model', 'Error_Type', 'Train_set', 'Test_set', 'R²', 'RMSE', 'MAE'])
# Train the model on mixed data
print("#" * 100)
print(f"[DFT - {MODEL_NAME}] Training {MODEL_NAME} on Mix data:")
print("-" * 100)

model = eventually_model

# evaluate on the train set
print(f"[Train_error] Evaluating {MODEL_NAME} on train set:")
metrics = model.evaluate(train_X, train_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Train',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the dft test set
print(f"[Test MIX -> DFT] Evaluating {MODEL_NAME} on DFT test set:")

metrics = model.evaluate(dft_test_X, dft_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'dft',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# evaluate on the exp test set
print(f"[Test MIX -> EXP] Evaluating {MODEL_NAME} on EXP test set:")
metrics = model.evaluate(exp_test_X, exp_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'exp',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}

# evaluate on the mixed test set
print(f"[Test MIX -> MIX] Evaluating {MODEL_NAME} on mixed test set:")
metrics = model.evaluate(mixed_test_X, mixed_test_y)
model_metrics.loc[len(model_metrics)] = {
'Model': MODEL_NAME,    
'Error_Type': 'Test',
'Train_set': 'mix',
'Test_set': 'mix',
'R²': metrics['r2'],
'RMSE': metrics['rmse'],
'MAE': metrics['mae']
}
# save the model metrics to a csv file
model_metrics.to_csv(os.path.join('./metrics', 'self_learning_metrics.csv'), index=False)
model_metrics
# Out:
# ####################################################################################################
# [DFT - Self Learning XGBoost] Training Self Learning XGBoost on Mix data:
# ----------------------------------------------------------------------------------------------------
# [Train_error] Evaluating Self Learning XGBoost on train set:
# Model Evaluation Results:
# Test set size: 8310
# Test set: R²: 0.9816 RMSE: 0.1069 MAE: 0.0797 MAPE: 10.3277%
# [Test MIX -> DFT] Evaluating Self Learning XGBoost on DFT test set:
# Model Evaluation Results:
# Test set size: 1963
# Test set: R²: 0.2442 RMSE: 0.7559 MAE: 0.5276 MAPE: 2678.2728%
# [Test MIX -> EXP] Evaluating Self Learning XGBoost on EXP test set:
# Model Evaluation Results:
# Test set size: 599
# Test set: R²: 0.7142 RMSE: 0.4315 MAE: 0.3129 MAPE: 39.6334%
# [Test MIX -> MIX] Evaluating Self Learning XGBoost on mixed test set:
# Model Evaluation Results:
# Test set size: 1198
# Test set: R²: 0.5086 RMSE: 0.5892 MAE: 0.4080 MAPE: 151.7525%
#                    Model Error_Type Train_set Test_set        R²      RMSE  \
# 0  Self Learning XGBoost      Train       mix      mix  0.981587  0.106866
# 1  Self Learning XGBoost       Test       mix      dft  0.244168  0.755948
# 2  Self Learning XGBoost       Test       mix      exp  0.714213  0.431488
# 3  Self Learning XGBoost       Test       mix      mix  0.508599  0.589242
#
#         MAE
# 0  0.079687
# 1  0.527580
# 2  0.312903
# 3  0.407999

# %% [markdown]
# **Compare to direct mix:**
# - the self-learning model has a better performance on the **exp test set**,
# - but the performance on the dft test set is not as good as the direct mix model.

# %% [markdown]
# - Sampled dft train data model is not good as the total dft train data model.
